# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('data/final_animedataset.csv')

# Display the first 10 rows
df.head(10)
# Out:
#    username  anime_id  my_score  user_id  gender              title type  \
# 0  karthiga        21         9  2255153  Female          One Piece   TV
# 1  karthiga        59         7  2255153  Female            Chobits   TV
# 2  karthiga        74         7  2255153  Female       Gakuen Alice   TV
# 3  karthiga       120         7  2255153  Female      Fruits Basket   TV
# 4  karthiga       178         7  2255153  Female       Ultra Maniac   TV
# 5  karthiga       210         7  2255153  Female            Ranma ½   TV
# 6  karthiga       232         6  2255153  Female  Cardcaptor Sakura   TV
# 7  karthiga       233         6  2255153  Female     Daa! Daa! Daa!   TV
# 8  karthiga       249         8  2255153  Female           InuYasha   TV
# 9  karthiga       269        10  2255153  Female             Bleach   TV
#
#   source  score  scored_by    rank  popularity  \
# 0  Manga   8.54     423868    91.0          35
# 1  Manga   7.53     175388  1546.0         188
# ...

# %%
# Export the first 10 rows to a new CSV file
df.head(10).to_csv('ffinal_animedataset10_rows.csv', index=False)

# %%
from supabase import create_client, Client

url = "https://yvspjnxnwdanqwymcwtw.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Inl2c3Bqbnhud2RhbnF3eW1jd3R3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NDU0NzIwMTIsImV4cCI6MjA2MTA0ODAxMn0.iVIH5OwBDXHM9yJGnQhxn7zkuFEmmQsZwGIKJiu3MRo"
supabase: Client = create_client(url, key)

# %%
df['rank'] = df['rank'].fillna(0).astype(int)

# %%
print(df.dtypes)
# Out:
# username       object
# anime_id        int64
# my_score        int64
# user_id         int64
# gender         object
# title          object
# type           object
# source         object
# score         float64
# scored_by       int64
# rank            int64
# popularity      int64
# genre          object
# dtype: object

# %%
df = df.drop_duplicates(subset="anime_id")

# %%
# Fix the "rank" column to be integer (if not already)
df['rank'] = df['rank'].fillna(0).astype(int)

# (optional) If there are other float columns that must be int, do the same:
# df['some_column'] = df['some_column'].fillna(0).astype(int)

# Now inserting will work
for record in df.to_dict(orient="records")[20:]:
    # supabase.table("final_animedataset").upsert(record, on_conflict=["anime_id"]).execute()
    supabase.table("final_animedataset").insert(record).execute()
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
c = 0

c += 1
print(f"done {c}/{len(df)})

# %%
# import pandas as pd

# # Load your data
# df = pd.read_csv('data/final_animedataset.csv')

# # Insert each row
# for record in df.to_dict(orient="records")[0:10]:
#     supabase.table("final_animedataset").insert(record).execute()
#     print("done")
